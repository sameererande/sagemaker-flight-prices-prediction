# %% [markdown]
# ## 1. Import Libraries

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from xgboost) (1.13.1)

# %%
# !pip install feature-engine
# Out:
# Requirement already satisfied: feature-engine in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (1.8.2)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from feature-engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from feature-engine) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from feature-engine) (1.5.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from feature-engine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from feature-engine) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pandas>=2.2.0->feature-engine) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pandas>=2.2.0->feature-engine) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature-engine) (1.16.0)

# %% [markdown]
# !pip install boto3                   #popular library for interacting with Amazon Web Services (AWS).
#
# !pip install sagemaker              #Here we need to use this if we run this code inside sagemaker then no need to use

# %%
# !pip install boto3                  #SDK for communication between python and sagemaker 
# !pip install sagemaker
# Out:
# Requirement already satisfied: boto3 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (1.35.63)
# Requirement already satisfied: botocore<1.36.0,>=1.35.63 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from boto3) (1.35.63)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from boto3) (0.10.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from botocore<1.36.0,>=1.35.63->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from botocore<1.36.0,>=1.35.63->boto3) (2.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.63->boto3) (1.16.0)
# Requirement already satisfied: sagemaker in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (2.233.0)
# Requirement already satisfied: attrs<24,>=23.1.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (23.2.0)
# Requirement already satisfied: boto3<2.0,>=1.34.142 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (1.35.63)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (2.2.1)
# Requirement already satisfied: docker in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (7.1.0)
# Requirement already satisfied: google-pasta in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (6.11.0)
# Requirement already satisfied: jsonschema in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (4.23.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (24.1)
# Requirement already satisfied: pandas in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (2.2.3)
# Requirement already satisfied: pathos in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (0.3.3)
# Requirement already satisfied: platformdirs in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (4.3.6)
# Requirement already satisfied: protobuf<5.0,>=3.12 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (4.25.5)
# Requirement already satisfied: psutil in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (5.9.0)
# Requirement already satisfied: pyyaml~=6.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (6.0.2)
# Requirement already satisfied: requests in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (2.32.3)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (1.0.14)
# Requirement already satisfied: sagemaker-mlflow in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (0.1.0)
# Requirement already satisfied: schema in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (3.0.0)
# Requirement already satisfied: tqdm in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (4.67.0)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker) (2.2.3)
# Requirement already satisfied: botocore<1.36.0,>=1.35.63 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.35.63)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from boto3<2.0,>=1.34.142->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from boto3<2.0,>=1.34.142->sagemaker) (0.10.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.21.0)
# Requirement already satisfied: pydantic<3.0.0,>=1.7.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.9.2)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from jsonschema->sagemaker) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from jsonschema->sagemaker) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from jsonschema->sagemaker) (0.10.6)
# Requirement already satisfied: pywin32>=304 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from docker->sagemaker) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from requests->sagemaker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from requests->sagemaker) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from requests->sagemaker) (2024.8.30)
# Requirement already satisfied: six in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pandas->sagemaker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pandas->sagemaker) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pandas->sagemaker) (2024.2)
# Requirement already satisfied: ppft>=1.7.6.9 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pathos->sagemaker) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pathos->sagemaker) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pathos->sagemaker) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pathos->sagemaker) (0.70.17)
# Requirement already satisfied: mlflow>=2.8 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sagemaker-mlflow->sagemaker) (2.18.0)
# Requirement already satisfied: colorama in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from tqdm->sagemaker) (0.4.6)
# Requirement already satisfied: mlflow-skinny==2.18.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.18.0)
# Requirement already satisfied: Flask<4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.14.0)
# Requirement already satisfied: graphene<4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.7)
# Requirement already satisfied: matplotlib<4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.9.2)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (18.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.5.2)
# Requirement already satisfied: scipy<2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.0.36)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.4)
# Requirement already satisfied: waitress<4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (8.1.7)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.38.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.43)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.28.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.28.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.15.1)
# Requirement already satisfied: Mako in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from alembic!=1.10.0,<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.3.6)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.2.5)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from Jinja2<4,>=3.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.2.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.1)
# Requirement already satisfied: google-auth~=2.0 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.36.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.0.11)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.2.15)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.49b1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\samee\anaconda3\ac\envs\new_project\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.18.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.6.1)

# %%
import os

import boto3

import pickle

import warnings

import numpy as np

import pandas as pd

import xgboost as xgb

import sklearn
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
	OneHotEncoder,
	OrdinalEncoder,
	StandardScaler,
	MinMaxScaler,
	PowerTransformer,
	FunctionTransformer
)

from feature_engine.outliers import Winsorizer
from feature_engine.datetime import DatetimeFeatures
from feature_engine.selection import SelectBySingleFeaturePerformance
from feature_engine.encoding import (
	RareLabelEncoder,
	MeanEncoder,
	CountFrequencyEncoder
)

import sagemaker
from sagemaker.estimator import Estimator
from sagemaker.inputs import TrainingInput
from sagemaker.tuner import (
    IntegerParameter,
    ContinuousParameter,
    HyperparameterTuner
)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\samee\AppData\Local\sagemaker\sagemaker\config.yaml

# %% [markdown]
# ## 2. Display Settings

# %%
pd.set_option("display.max_columns", None)

# %%
sklearn.set_config(transform_output="pandas")

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 3. Read Datasets

# %%
train = pd.read_csv("train.csv")
train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0               Indigo      2019-05-15     Delhi      Cochin  17:05:00
# 1    Multiple Carriers      2019-05-15     Delhi      Cochin  07:10:00
# 2            Air India      2019-06-18     Delhi      Cochin  18:05:00
# 3    Multiple Carriers      2019-05-27     Delhi      Cochin  12:50:00
# 4    Multiple Carriers      2019-03-03     Delhi      Cochin  16:00:00
# ..                 ...             ...       ...         ...       ...
# 635        Jet Airways      2019-03-12  Banglore   New Delhi  18:55:00
# 636             Indigo      2019-05-12  Banglore       Delhi  07:10:00
# 637  Multiple Carriers      2019-03-09     Delhi      Cochin  06:50:00
# 638          Air India      2019-03-01  Banglore   New Delhi  05:50:00
# 639        Jet Airways      2019-05-01   Kolkata    Banglore  20:25:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       22:15:00       310          1.0                      No Info   6027
# 1       22:30:00       920          1.0                      No Info   6513
# 2       21:10:00       185          0.0                      No Info   5201
# 3       21:00:00       490          1.0                      No Info   7005
# 4       01:35:00       575          1.0                      No Info  21226
# ..           ...       ...          ...                          ...    ...
# 635     16:10:00      1275          1.0  In-flight meal not included  11087
# 636     10:05:00       175          0.0                      No Info   4823
# 637     19:15:00       745          1.0  In-flight meal not included  14817
# 638     16:20:00       630          2.0              Change airports  15119
# 639     23:35:00      1630          1.0                      No Info  11467
#
# [640 rows x 10 columns]

# %%
val = pd.read_csv("val.csv")
val
# Out:
#          airline date_of_journey    source destination  dep_time arrival_time  \
# 0         Indigo      2019-05-21   Chennai     Kolkata  19:35:00     21:55:00
# 1       Air Asia      2019-04-15   Kolkata    Banglore  10:20:00     12:55:00
# 2    Jet Airways      2019-04-18     Delhi      Cochin  11:00:00     14:15:00
# 3         Indigo      2019-03-09  Banglore   New Delhi  16:55:00     21:50:00
# 4    Jet Airways      2019-05-18     Delhi      Cochin  19:10:00     12:35:00
# ..           ...             ...       ...         ...       ...          ...
# 155    Air India      2019-05-15     Delhi      Cochin  13:05:00     09:25:00
# 156       Indigo      2019-05-21     Delhi      Cochin  10:35:00     01:30:00
# 157     Spicejet      2019-05-18    Mumbai   Hyderabad  22:45:00     00:15:00
# 158       Indigo      2019-06-18  Banglore       Delhi  16:55:00     19:55:00
# 159  Jet Airways      2019-05-24   Kolkata    Banglore  20:00:00     20:45:00
#
#      duration  total_stops               additional_info  price
# 0         140          0.0                       No Info   3597
# 1         155          0.0                       No Info   4409
# 2         195          0.0   In-flight meal not included   5443
# 3         295          1.0                       No Info   4259
# 4        1045          2.0                       No Info  15129
# ..        ...          ...                           ...    ...
# 155      1220          2.0                       No Info  10975
# 156       895          1.0                       No Info   6794
# 157        90          0.0  No check-in baggage included   1965
# 158       180          0.0                       No Info   4823
# 159      1485          1.0   In-flight meal not included  10844
#
# [160 rows x 10 columns]

# %%
test = pd.read_csv("test.csv")
test
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0            Air India      2019-06-21   Chennai     Kolkata  11:40:00
# 1            Air India      2019-05-12   Kolkata    Banglore  09:25:00
# 2            Air India      2019-06-06   Kolkata    Banglore  14:30:00
# 3          Jet Airways      2019-03-24  Banglore   New Delhi  19:55:00
# 4               Indigo      2019-06-06  Banglore       Delhi  00:25:00
# ..                 ...             ...       ...         ...       ...
# 195        Jet Airways      2019-06-09     Delhi      Cochin  18:25:00
# 196        Jet Airways      2019-03-18  Banglore   New Delhi  11:40:00
# 197        Jet Airways      2019-05-12   Kolkata    Banglore  21:10:00
# 198        Jet Airways      2019-06-06     Delhi      Cochin  05:30:00
# 199  Multiple Carriers      2019-05-09     Delhi      Cochin  10:35:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       13:55:00       135          0.0                      No Info   4667
# 1       18:30:00       545          1.0                      No Info   8576
# 2       12:30:00      1320          2.0                      No Info  15894
# 3       22:35:00       160          0.0                      No Info   7229
# 4       03:15:00       170          0.0                      No Info   3943
# ..           ...       ...          ...                          ...    ...
# 195     12:35:00      1090          2.0                      No Info  14237
# 196     05:05:00      1045          1.0  In-flight meal not included  11087
# 197     04:40:00       450          1.0  In-flight meal not included   8586
# 198     04:25:00      1375          2.0  In-flight meal not included  10368
# 199     19:00:00       505          1.0                      No Info   9103
#
# [200 rows x 10 columns]

# %% [markdown]
# ## 4. Preprocessing Operations

# %%
# airline
air_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("grouper", RareLabelEncoder(tol=0.1, replace_with="Other", n_categories=2)),
    ("encoder", OneHotEncoder(sparse_output=False, handle_unknown="ignore"))
])

#doj
feature_to_extract = ["month", "week", "day_of_week", "day_of_year"]

doj_transformer = Pipeline(steps=[
    ("dt", DatetimeFeatures(features_to_extract=feature_to_extract, yearfirst=True, format="mixed")),
    ("scaler", MinMaxScaler())
])

# source & destination
location_pipe1 = Pipeline(steps=[
    ("grouper", RareLabelEncoder(tol=0.1, replace_with="Other", n_categories=2)),
    ("encoder", MeanEncoder()),
    ("scaler", PowerTransformer())
])

def is_north(X):
    columns = X.columns.to_list()
    north_cities = ["Delhi", "Kolkata", "Mumbai", "New Delhi"]
    return (
        X
        .assign(**{
            f"{col}_is_north": X.loc[:, col].isin(north_cities).astype(int)
            for col in columns
        })
        .drop(columns=columns)
    )

location_transformer = FeatureUnion(transformer_list=[
    ("part1", location_pipe1),
    ("part2", FunctionTransformer(func=is_north))
])

# dep_time & arrival_time
time_pipe1 = Pipeline(steps=[
    ("dt", DatetimeFeatures(features_to_extract=["hour", "minute"])),
    ("scaler", MinMaxScaler())
])

def part_of_day(X, morning=4, noon=12, eve=16, night=20):
    columns = X.columns.to_list()
    X_temp = X.assign(**{
        col: pd.to_datetime(X.loc[:, col]).dt.hour
        for col in columns
    })

    return (
        X_temp
        .assign(**{
            f"{col}_part_of_day": np.select(
                [X_temp.loc[:, col].between(morning, noon, inclusive="left"),
                 X_temp.loc[:, col].between(noon, eve, inclusive="left"),
                 X_temp.loc[:, col].between(eve, night, inclusive="left")],
                ["morning", "afternoon", "evening"],
                default="night"
            )
            for col in columns
        })
        .drop(columns=columns)
    )

time_pipe2 = Pipeline(steps=[
    ("part", FunctionTransformer(func=part_of_day)),
    ("encoder", CountFrequencyEncoder()),
    ("scaler", MinMaxScaler())
])

time_transformer = FeatureUnion(transformer_list=[
    ("part1", time_pipe1),
    ("part2", time_pipe2)
])

# duration
class RBFPercentileSimilarity(BaseEstimator, TransformerMixin):
    def __init__(self, variables=None, percentiles=[0.25, 0.5, 0.75], gamma=0.1):
        self.variables = variables
        self.percentiles = percentiles
        self.gamma = gamma


    def fit(self, X, y=None):
        if not self.variables:
            self.variables = X.select_dtypes(include="number").columns.to_list()

        self.reference_values_ = {
            col: (
                X
                .loc[:, col]
                .quantile(self.percentiles)
                .values
                .reshape(-1, 1)
            )
            for col in self.variables
        }

        return self


    def transform(self, X):
        objects = []
        for col in self.variables:
            columns = [f"{col}_rbf_{int(percentile * 100)}" for percentile in self.percentiles]
            obj = pd.DataFrame(
                data=rbf_kernel(X.loc[:, [col]], Y=self.reference_values_[col], gamma=self.gamma),
                columns=columns
            )
            objects.append(obj)
        return pd.concat(objects, axis=1)
    

def duration_category(X, short=180, med=400):
    return (
        X
        .assign(duration_cat=np.select([X.duration.lt(short),
                                    X.duration.between(short, med, inclusive="left")],
                                    ["short", "medium"],
                                    default="long"))
        .drop(columns="duration")
    )

def is_over(X, value=1000):
    return (
        X
        .assign(**{
            f"duration_over_{value}": X.duration.ge(value).astype(int)
        })
        .drop(columns="duration")
    )

duration_pipe1 = Pipeline(steps=[
    ("rbf", RBFPercentileSimilarity()),
    ("scaler", PowerTransformer())
])

duration_pipe2 = Pipeline(steps=[
    ("cat", FunctionTransformer(func=duration_category)),
    ("encoder", OrdinalEncoder(categories=[["short", "medium", "long"]]))
])

duration_union = FeatureUnion(transformer_list=[
    ("part1", duration_pipe1),
    ("part2", duration_pipe2),
    ("part3", FunctionTransformer(func=is_over)),
    ("part4", StandardScaler())
])

duration_transformer = Pipeline(steps=[
    ("outliers", Winsorizer(capping_method="iqr", fold=1.5)),
    ("imputer", SimpleImputer(strategy="median")),
    ("union", duration_union)
])

# total_stops
def is_direct(X):
    return X.assign(is_direct_flight=X.total_stops.eq(0).astype(int))


total_stops_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("", FunctionTransformer(func=is_direct))
])

# additional_info
info_pipe1 = Pipeline(steps=[
    ("group", RareLabelEncoder(tol=0.1, n_categories=2, replace_with="Other")),
    ("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

def have_info(X):
    return X.assign(additional_info=X.additional_info.ne("No Info").astype(int))

info_union = FeatureUnion(transformer_list=[
("part1", info_pipe1),
("part2", FunctionTransformer(func=have_info))
])

info_transformer = Pipeline(steps=[
("imputer", SimpleImputer(strategy="constant", fill_value="unknown")),
("union", info_union)
])

# column transformer
column_transformer = ColumnTransformer(transformers=[
("air", air_transformer, ["airline"]),
("doj", doj_transformer, ["date_of_journey"]),
("location", location_transformer, ["source", 'destination']),
("time", time_transformer, ["dep_time", "arrival_time"]),
("dur", duration_transformer, ["duration"]),
("stops", total_stops_transformer, ["total_stops"]),
("info", info_transformer, ["additional_info"])
], remainder="passthrough")

# feature selector
estimator = RandomForestRegressor(n_estimators=10, max_depth=3, random_state=42)

selector = SelectBySingleFeaturePerformance(
estimator=estimator,
scoring="r2",
threshold=0.1
) 

# preprocessor
preprocessor = Pipeline(steps=[
("ct", column_transformer),
("selector", selector)
])

# %%
preprocessor.fit(
    train.drop(columns="price"),
    train.price.copy()
)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('air',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('grouper',
#                                                                    RareLabelEncoder(n_categories=2,
#                                                                                     replace_with='Other',
#                                                                                     tol=0.1)),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline']),
#                                                  ('doj',
#                                                   Pipeline(steps=[('dt',
#                                                                    Datetime...
#                                                                                                                                      replace_with='Other',
#                                                                                                                                      tol=0.1)),
#                                                                                                                    ('encoder',
#                                                                                                                     OneHotEncoder(handle_unknown='ignore',
#                                                                                                                                   sparse_output=False))])),
#                                                                                                   ('part2',
#                                                                                                    FunctionTransformer(func=<function have_info at 0x000002197DAE42C0>))]))]),
#                                                   ['additional_info'])])),
#                 ('selector',
#                  SelectBySingleFeaturePerformance(estimator=RandomForestRegressor(max_depth=3,
#                                                                                   n_estimators=10,
#                                                                                   random_state=42),
#                                                   scoring='r2',
#                                                   threshold=0.1))])

# %%
preprocessor.transform(train.drop(columns="price"))
# Out:
#      air__airline_Jet Airways  air__airline_Other  doj__date_of_journey_month  \
# 0                         0.0                 0.0                    0.666667
# 1                         0.0                 0.0                    0.666667
# 2                         0.0                 0.0                    1.000000
# 3                         0.0                 0.0                    0.666667
# 4                         0.0                 0.0                    0.000000
# ..                        ...                 ...                         ...
# 635                       1.0                 0.0                    0.000000
# 636                       0.0                 0.0                    0.666667
# 637                       0.0                 0.0                    0.000000
# 638                       0.0                 0.0                    0.000000
# 639                       1.0                 0.0                    0.666667
#
#      doj__date_of_journey_week  location__source  location__destination  \
# 0                     0.647059          0.963946               0.960350
# 1                     0.647059          0.963946               0.960350
# 2                     0.941176          0.963946               0.960350
# 3                     0.764706          0.963946               0.960350
# 4                     0.000000          0.963946               0.960350
# ..                         ...               ...                    ...
# 635                   0.117647         -1.230536              -0.854212
# 636                   0.588235         -1.230536              -1.830057
# 637                   0.058824          0.963946               0.960350
# 638                   0.000000         -1.230536              -0.854212
# 639                   0.529412         -0.011920              -0.081968
#
#      dur__duration_rbf_25  dur__duration_cat  dur__duration_over_1000  \
# 0               -0.368298                1.0                        0
# 1               -0.368298                2.0                        0
# 2               -0.364777                1.0                        0
# 3               -0.368298                2.0                        0
# 4               -0.368298                2.0                        0
# ..                    ...                ...                      ...
# 635             -0.368298                2.0                        1
# 636              3.067125                0.0                        0
# 637             -0.368298                2.0                        0
# 638             -0.368298                2.0                        0
# 639             -0.368298                2.0                        1
#
#      dur__duration  stops__total_stops  stops__is_direct_flight
# 0        -0.684948                 1.0                        0
# 1         0.536380                 1.0                        0
# 2        -0.935220                 0.0                        1
# 3        -0.324556                 1.0                        0
# 4        -0.154371                 1.0                        0
# ..             ...                 ...                      ...
# 635       1.247152                 1.0                        0
# 636      -0.955241                 0.0                        1
# 637       0.185999                 1.0                        0
# 638      -0.044251                 2.0                        0
# 639       1.957925                 1.0                        0
#
# [640 rows x 12 columns]

# %% [markdown]
# ## 4. Preprocess Data and Upload to Bucket

# %%
BUCKET_NAME = "sagemaker-flights-bucket"

DATA_PREFIX = "data"

# %%
def get_file_name(name):
    return f"{name}-pre.csv"

# %% [markdown]
# **Exporting data** refers to saving a dataset or DataFrame into an external file format for use outside of the Python environment.

# %%
def export_data(data, name, pre):
    # split data into X and y subsets
    X = data.drop(columns="price")
    y = data.price.copy()
    
    # transformation
    X_pre = pre.transform(X)
    
    # exporting
    file_name = get_file_name(name)
    (
        y
        .to_frame()
        .join(X_pre)
        .to_csv(file_name, index=False, header=False)  # we Want to data in csv file format this is sagemaker format
    )

# %%
def upload_to_bucket(name):
    file_name = get_file_name(name)
    
    (
        boto3
        .Session()  # We are working with this environment so called session
        .resource("s3")    #here we want s3 
        .Bucket(BUCKET_NAME)    #Here give bucket
        .Object(os.path.join(DATA_PREFIX, f"{name}/{name}.csv"))  #Inside bucket where we want to save our file , first we will create folder Data Prefix
        #Then file name we will give
        .upload_file(file_name)   #File name we want to upload
    )

# %%
#Combination of both methods here

# %%
def export_and_upload_bucket(data, name, pre): #Here in input we need data, give name of data and preprocessor
    export_data(data, name, pre)  #Here we are exporting our preprocessed data
    upload_to_bucket(name)  #Here we are uploading that preprocessed data inside bucket

# %%
export_and_upload_bucket(train, "train", preprocessor)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 export_and_upload_bucket(train, "train", preprocessor)
#
# Cell In[18], line 3, in export_and_upload_bucket(data, name, pre)
#       1 def export_and_upload_bucket(data, name, pre):
#       2     export_data(data, name, pre)
# ----> 3     upload_to_bucket(name)
#
# Cell In[17], line 10, in upload_to_bucket(name)
#       1 def upload_to_bucket(name):
#       2     file_name = get_file_name(name)
#       4     (
#       5         boto3
#       6         .Session()
#       7         .resource("s3")
#       8         .Bucket(BUCKET_NAME)
#       9         .Object(os.path.join(DATA_PREFIX, f"{name}/{name}.csv"))
# ---> 10         .upload_file(file_name)
#      11     )
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\boto3\s3\inject.py:320, in object_upload_file(self, Filename, ExtraArgs, Callback, Config)
#     289 def object_upload_file(
#     290     self, Filename, ExtraArgs=None, Callback=None, Config=None
#     291 ):
#     292     """Upload a file to an S3 object.
#     293
#     294     Usage::
#    (...)
#     318         transfer.
#     319     """
# --> 320     return self.meta.client.upload_file(
#     321         Filename=Filename,
#     322         Bucket=self.bucket_name,
#     323         Key=self.key,
#     324         ExtraArgs=ExtraArgs,
#     325         Callback=Callback,
#     326         Config=Config,
#     327     )
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\boto3\s3\inject.py:145, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     110 """Upload a file to an S3 object.
#     111
#     112 Usage::
#    (...)
#     142     transfer.
#     143 """
#     144 with S3Transfer(self, Config) as transfer:
# --> 145     return transfer.upload_file(
#     146         filename=Filename,
#     147         bucket=Bucket,
#     148         key=Key,
#     149         extra_args=ExtraArgs,
#     150         callback=Callback,
#     151     )
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\boto3\s3\transfer.py:372, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     368 future = self._manager.upload(
#     369     filename, bucket, key, extra_args, subscribers
#     370 )
#     371 try:
# --> 372     future.result()
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#     377 except ClientError as e:
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\s3transfer\futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\s3transfer\futures.py:264, in TransferCoordinator.result(self)
#     261 # Once done waiting, raise an exception if present or return the
#     262 # final result.
#     263 if self._exception:
# --> 264     raise self._exception
#     265 return self._result
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\s3transfer\tasks.py:135, in Task.__call__(self)
#     131     # If the task is not done (really only if some other related
#     132     # task to the TransferFuture had failed) then execute the task's
#     133     # main() method.
#     134     if not self._transfer_coordinator.done():
# --> 135         return self._execute_main(kwargs)
#     136 except Exception as e:
#     137     self._log_and_set_exception(e)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\s3transfer\tasks.py:158, in Task._execute_main(self, kwargs)
#     155 # Log what is about to be executed.
#     156 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 158 return_value = self._main(**kwargs)
#     159 # If the task is the final task, then set the TransferFuture's
#     160 # value to the return value from main().
#     161 if self._is_final:
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\s3transfer\upload.py:762, in PutObjectTask._main(self, client, fileobj, bucket, key, extra_args)
#     753 """
#     754 :param client: The client to use when calling PutObject
#     755 :param fileobj: The file to upload.
#    (...)
#     759     used in the upload.
#     760 """
#     761 with fileobj as body:
# --> 762     client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\client.py:1005, in BaseClient._make_api_call(self, operation_name, api_params)
#    1001     maybe_compress_request(
#    1002         self.meta.config, request_dict, operation_model
#    1003     )
#    1004     apply_request_checksum(request_dict)
# -> 1005     http, parsed_response = self._make_request(
#    1006         operation_model, request_dict, request_context
#    1007     )
#    1009 self.meta.events.emit(
#    1010     f'after-call.{service_id}.{operation_name}',
#    1011     http_response=http,
#    (...)
#    1014     context=request_context,
#    1015 )
#    1017 if http.status_code >= 300:
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\client.py:1029, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1027 def _make_request(self, operation_model, request_dict, request_context):
#    1028     try:
# -> 1029         return self._endpoint.make_request(operation_model, request_dict)
#    1030     except Exception as e:
#    1031         self.meta.events.emit(
#    1032             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1033             exception=e,
#    1034             context=request_context,
#    1035         )
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\endpoint.py:196, in Endpoint._send_request(self, request_dict, operation_model)
#     194 context = request_dict['context']
#     195 self._update_retries_context(context, attempts)
# --> 196 request = self.create_request(request_dict, operation_model)
#     197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
#     200 while self._needs_retry(
#     201     attempts,
#     202     operation_model,
#    (...)
#     205     exception,
#     206 ):
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\endpoint.py:132, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = f'request-created.{service_id}.{operation_model.name}'
# --> 132     self._event_emitter.emit(
#     133         event_name,
#     134         request=request,
#     135         operation_name=operation_model.name,
#     136     )
#     137 prepared_request = self.prepare_request(request)
#     138 return prepared_request
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\signers.py:105, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     100 def handler(self, operation_name=None, request=None, **kwargs):
#     101     # This is typically hooked up to the "request-created" event
#     102     # from a client's event emitter.  When a new request is created
#     103     # this method is invoked to sign the request.
#     104     # Don't call this method directly.
# --> 105     return self.sign(operation_name, request)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\signers.py:197, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     194     else:
#     195         raise e
# --> 197 auth.add_auth(request)
#
# File ~\anaconda3\AC\envs\new_project\Lib\site-packages\botocore\auth.py:423, in SigV4Auth.add_auth(self, request)
#     421 def add_auth(self, request):
#     422     if self.credentials is None:
# --> 423         raise NoCredentialsError()
#     424     datetime_now = datetime.datetime.utcnow()
#     425     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
export_and_upload_bucket(val, "val", preprocessor)

# %%
export_and_upload_bucket(test, "test", preprocessor)

# %% [markdown]
# ## 5. Model and Hyperparameter Tuning Set-up

# %%
session = sagemaker.Session()  # key class used to interact with SageMaker resources.
region_name = session.boto_region_name #retrieves the AWS region associated with the current session.

# %%
output_path = f"s3://{BUCKET_NAME}/model/output"  #To save train model we use this

# %%
model = Estimator(
    image_uri=sagemaker.image_uris.retrieve("xgboost", region_name, "1.2-1"), #This retrieves the Docker image URI for the specified framework (xgboost), the region (region_name), and version (1.2-1).
    role=sagemaker.get_execution_role(), #Gets the AWS Identity and Access Management (IAM) execution role associated with SageMaker.Grants permissions for SageMaker to access AWS services such as S3 (for data storage) and CloudWatch (for logging).
    instance_count=1, #Specifies the number of EC2 instances to use for training.Determines the scale of computation resources.
    instance_type="ml.m4.xlarge", #Specifies the type of EC2 instance to use for training.
    volume_size=5,  #Allocates 5 GB of storage to the training instance in S#.
    output_path=output_path,  #Specifies the S3 path where SageMaker will save the model artifacts after training.
    use_spot_instances=True, #Configures SageMaker to use Spot Instances, which are lower-cost, spare EC2 instances.
    max_run=300,  #Sets the maximum runtime for the training job in seconds. Here, it's 300 seconds
    max_wait=600, #Sets the maximum wait time in seconds for the training job when using Spot Instances.
    sagemaker_session=session  #Provides the session object, which manages interactions with SageMaker.
)

# %%
model.set_hyperparameters(
    objective="reg:linear", #Consider using "reg:squarederror"
    num_round=10, #Indicates the number of boosting rounds (iterations).
    eta=0.1, #Learning rate that scales the weight updates during training
    max_depth=5,  #Limits the depth of trees
    subsample=0.8, #Fraction of training samples randomly selected for each boosting round. 
    colsample_bytree=0.8, #Fraction of features (columns) randomly chosen for each tree. 
    alpha=0.1 #L1 regularization term on weights. 
)

# %%
hyperparameter_ranges = {
    "eta": ContinuousParameter(0.05, 0.2), #Specifies that the learning rate (eta) can take continuous values between 0.05 and 0.2.
    "alpha": ContinuousParameter(0, 1),
    "max_depth": IntegerParameter(3, 5)
}

# %% [markdown]
# The **HyperparameterTuner** is a class in AWS SageMaker used to automate the process of finding the best hyperparameter configuration for a machine learning model.

# %%
tuner = HyperparameterTuner(
    estimator=model,
    objective_metric_name="validation:rmse",  # root mean square error on the validation set.
    hyperparameter_ranges=hyperparameter_ranges,
    strategy="Bayesian",  # Uses Bayesian optimization to explore the parameter space efficiently.
    objective_type="Minimize"  #Reduces the metric value (e.g., RMSE, loss).
)

# %% [markdown]
# ## 6. Data Channels

# %%
def get_data_channel(name):  #Here we are telling location of dataset
    bucket_path = f"s3://{BUCKET_NAME}/{DATA_PREFIX}/{name}"
    return TrainingInput(bucket_path, content_type="csv")

# %%
train_data_channel = get_data_channel("train")
train_data_channel

# %%
val_data_channel = get_data_channel("val")

# %%
data_channels = {
    "train": train_data_channel,
    "validation": val_data_channel
}

# %% [markdown]
# ## 7. Train and Tune the Model

# %%
tuner.fit(data_channels)  #Here we are giving data channels for fit data
# Out:
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# ......................................!

# %%
#tuner.best_estimator().deploy()

# %% [markdown]
# ## 8. Model Evaluation

# %%
with open("xgboost-model", "rb") as f:
    best_model = pickle.load(f)
    
best_model

# %%
def evaluate_model(name):
    file_name = get_file_name(name)
    data = pd.read_csv(file_name)
    
    X = xgb.DMatrix(data.iloc[:, 1:]) # is using XGBoost's DMatrix object to handle data input for the XGBoost algorithm.
    y = data.iloc[:, 0].copy()
    
    pred = best_model.predict(X)
    
    return r2_score(y, pred)

# %%
evaluate_model("train")
# Out:
# -0.5000379618028745

# %%
evaluate_model("val")
# Out:
# -0.4516233294836658

# %%
evaluate_model("test")
# Out:
# -0.43416313174551946
